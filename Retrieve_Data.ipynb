# %%
# !kaggle competitions download -c birdsong-recognition
# Out:
# ...
#   0%|          | 0.00/22.1G [00:00<?, ?B/s]
#   0%|          | 1.00M/22.1G [00:00<49:49, 7.94MB/s]
#   0%|          | 5.00M/22.1G [00:01<1:14:13, 5.33MB/s]
#   0%|          | 6.00M/22.1G [00:01<1:08:42, 5.76MB/s]
#   0%|          | 10.0M/22.1G [00:01<51:16, 7.72MB/s]
#   0%|          | 12.0M/22.1G [00:02<1:06:20, 5.96MB/s]
#   0%|          | 16.0M/22.1G [00:02<49:54, 7.92MB/s]
#   0%|          | 18.0M/22.1G [00:03<1:15:04, 5.27MB/s]
#   0%|          | 20.0M/22.1G [00:03<1:03:05, 6.27MB/s]
#   0%|          | 24.0M/22.1G [00:03<47:13, 8.37MB/s]
#   0%|          | 26.0M/22.1G [00:04<1:10:28, 5.61MB/s]
#   0%|          | 28.0M/22.1G [00:04<59:54, 6.60MB/s]
#   0%|          | 32.0M/22.1G [00:04<45:07, 8.76MB/s]
#   0%|          | 35.0M/22.1G [00:04<52:16, 7.56MB/s]
#   0%|          | 39.0M/22.1G [00:05<39:39, 9.97MB/s]
#   0%|          | 42.0M/22.1G [00:05<58:30, 6.75MB/s]
#   0%|          | 47.0M/22.1G [00:06<43:54, 9.00MB/s]
#   0%|          | 50.0M/22.1G [00:07<1:16:33, 5.16MB/s]
# ...

# %%
import zipfile
with zipfile.ZipFile("./birdsong-recognition.zip", 'r') as zip_ref:
    zip_ref.extractall("./data/")

# %%
import os
for dirname, _, filenames in os.walk("data/train_audio/"):
    print(dirname)
# Out:
# data/train_audio/
# data/train_audio/aldfly
# data/train_audio/ameavo
# data/train_audio/amebit
# data/train_audio/amecro
# data/train_audio/amegfi
# data/train_audio/amekes
# data/train_audio/amepip
# data/train_audio/amered
# data/train_audio/amerob
# data/train_audio/amewig
# data/train_audio/amewoo
# data/train_audio/amtspa
# data/train_audio/annhum
# data/train_audio/astfly
# data/train_audio/baisan
# data/train_audio/baleag
# data/train_audio/balori
# data/train_audio/banswa
# data/train_audio/barswa
# data/train_audio/bawwar
# data/train_audio/belkin1
# data/train_audio/belspa2
# data/train_audio/bewwre
# data/train_audio/bkbcuc
# data/train_audio/bkbmag1
# data/train_audio/bkbwar
# data/train_audio/bkcchi
# data/train_audio/bkchum
# data/train_audio/bkhgro
# data/train_audio/bkpwar
# data/train_audio/bktspa
# data/train_audio/blkpho
# data/train_audio/blugrb1
# data/train_audio/blujay
# data/train_audio/bnhcow
# data/train_audio/boboli
# data/train_audio/bongul
# ...
